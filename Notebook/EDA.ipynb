# %%
import pandas as pd
import numpy as np
# import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import os
warnings.filterwarnings('ignore')

# %%
for _,dirnames, filenames in os.walk('C:\\Users\\ajaym\\Desktop\\iris'):
    for filename in filenames:
        print(filename)
# Out:
# archive (2).zip
# Iris.csv
# Untitled.ipynb
# Untitled-checkpoint.ipynb

# %%
mydata = pd.read_csv('Iris.csv')

mydata.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
mydata.head()
# Out:
#    id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df = mydata.copy()

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.shape
# Out:
# (150, 6)

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.describe().T
# Out:
#                count       mean        std  min    25%    50%     75%    max
# Id             150.0  75.500000  43.445368  1.0  38.25  75.50  112.75  150.0
# SepalLengthCm  150.0   5.843333   0.828066  4.3   5.10   5.80    6.40    7.9
# SepalWidthCm   150.0   3.054000   0.433594  2.0   2.80   3.00    3.30    4.4
# PetalLengthCm  150.0   3.758667   1.764420  1.0   1.60   4.35    5.10    6.9
# PetalWidthCm   150.0   1.198667   0.763161  0.1   0.30   1.30    1.80    2.5

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
categorical_features = [feature for feature in df.columns if df[feature].dtype == 'O']

categorical_features
# Out:
# ['Species']

# %%
numerical_features = [feature for feature in df.columns if df[feature].dtype !='O']

numerical_features
# Out:
# ['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']

# %%
df.corr(numeric_only = True)
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %%
sns.heatmap(df.corr(numeric_only = True))
# Out:
# <Axes: >

# %%
df.drop('Id', axis = 1, inplace = True)

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ## UNIVARIATE ANALYSIS

# %%
fig, ax = plt.subplots(2, 2, figsize = (30, 15))
plt.suptitle('Distribution of Independent Feature')
plt.subplot(221)
plt.title('Distribution of SepalLengthCm')
sns.histplot(data = df, x = "SepalLengthCm", kde = True, color = 'red', legend = True)

plt.subplot(222)
plt.title('Distribution of SepalWidthCm')
sns.histplot(data = df, x = "SepalWidthCm", kde = True, color = 'red',legend = True)

plt.subplot(223)
plt.title('Distribution of PetalLengthCm')
sns.histplot(data = df, x = "PetalLengthCm", kde = True, color = 'red', legend = True)

plt.subplot(224)
plt.title('Distribution of PetalWidthCm')
sns.histplot(data = df, x = "PetalWidthCm", kde = True, color = 'red', legend = True)

plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 5))
plt.suptitle('Distribution of Dependent Feature')
plt.subplot(121)
plt.title('Distribution of Species')
sns.countplot(data = df, x = 'Species')
for container in ax[0].containers:
    ax[0].bar_label(container, color = 'black')

plt.subplot(122)
plt.pie(x = df.Species.value_counts(), labels = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], autopct = '%.2f%%')

plt.show()

# %% [markdown]
# ## BIVARIATE ANALYSIS

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
grouped_df = df.groupby(by = 'Species').mean().T

# %%
grouped_df = pd.DataFrame(grouped_df)

# %%
grouped_df
# Out:
# Species        Iris-setosa  Iris-versicolor  Iris-virginica
# SepalLengthCm        5.006            5.936           6.588
# SepalWidthCm         3.418            2.770           2.974
# PetalLengthCm        1.464            4.260           5.552
# PetalWidthCm         0.244            1.326           2.026

# %%
Iris_virginica_df = df[df.Species == 'Iris-virginica']

# %%
Iris_virginica_df.shape
# Out:
# (50, 5)

# %%
Iris_setosa_df = df[df.Species == 'Iris-setosa']

# %%
Iris_setosa_df.shape
# Out:
# (50, 5)

# %%
Iris_versicolor_df = df[df.Species == 'Iris-versicolor']

# %%
Iris_versicolor_df.shape
# Out:
# (50, 5)

# %%
Iris_versicolor_df.head()
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# 50            7.0           3.2            4.7           1.4  Iris-versicolor
# 51            6.4           3.2            4.5           1.5  Iris-versicolor
# 52            6.9           3.1            4.9           1.5  Iris-versicolor
# 53            5.5           2.3            4.0           1.3  Iris-versicolor
# 54            6.5           2.8            4.6           1.5  Iris-versicolor

# %%
grouped_df
# Out:
# Species        Iris-setosa  Iris-versicolor  Iris-virginica
# SepalLengthCm        5.006            5.936           6.588
# SepalWidthCm         3.418            2.770           2.974
# PetalLengthCm        1.464            4.260           5.552
# PetalWidthCm         0.244            1.326           2.026

# %%
fig, ax = plt.subplots(1, 4, figsize = (15, 5))
plt.suptitle('Properties of Iris-versicolor')
plt.subplot(141)
sns.histplot(data = Iris_versicolor_df, x = 'SepalLengthCm')

plt.subplot(142)
sns.histplot(data = Iris_versicolor_df, x = 'SepalWidthCm')

plt.subplot(143)
sns.histplot(data = Iris_versicolor_df, x = 'PetalLengthCm')

plt.subplot(144)
sns.histplot(data = Iris_versicolor_df, x = 'PetalWidthCm')


plt.show()

# %%
fig, ax = plt.subplots(1, 4, figsize = (15, 5))
plt.suptitle('Properties of Iris-setosa')
plt.subplot(141)
sns.histplot(data = Iris_setosa_df, x = 'SepalLengthCm')

plt.subplot(142)
sns.histplot(data = Iris_setosa_df, x = 'SepalWidthCm')

plt.subplot(143)
sns.histplot(data = Iris_setosa_df, x = 'PetalLengthCm')

plt.subplot(144)
sns.histplot(data = Iris_setosa_df, x = 'PetalWidthCm')


plt.show()

# %%
fig, ax = plt.subplots(1, 4, figsize = (15, 5))
plt.suptitle('Properties of Iris-virginica')
plt.subplot(141)
sns.histplot(data = Iris_virginica_df, x = 'SepalLengthCm')

plt.subplot(142)
sns.histplot(data = Iris_virginica_df, x = 'SepalWidthCm')

plt.subplot(143)
sns.histplot(data = Iris_virginica_df, x = 'PetalLengthCm')

plt.subplot(144)
sns.histplot(data = Iris_virginica_df, x = 'PetalWidthCm')


plt.show()

# %%
sns.pairplot(data = df, hue = 'Species')
